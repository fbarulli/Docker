# %%
# !docker image build . -t my_image:latest
# Out:
# [+] Building 0.0s (0/0)  docker:desktop-linux
# [+] Building 0.0s (0/0)  docker:desktop-linux
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 385B                                       0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 385B                                       0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from dockerfile                       0.0s
# ...

# %%
# !docker image ls
# Out:
# REPOSITORY   TAG       IMAGE ID       CREATED        SIZE
# my_image     latest    690a44b3a51e   15 hours ago   750MB

# %%
# !docker container run -p 5000:5000 -d my_image:latest
# Out:
# a4216cc62c43c4ce73d205d88deb424d10ae3a47d58fd55d4803de69058a3c04

# %%
# !sudo lsof -i :5000
# Out:
# Password:sudo: a password is required
